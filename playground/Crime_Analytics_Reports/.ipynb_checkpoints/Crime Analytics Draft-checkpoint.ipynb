# %% [markdown]
# # This is a report by Jiancheng
# ## Powered by [Bokeh](https://github.com/bokeh/bokeh), [Seaborn](http://web.stanford.edu/~mwaskom/software/seaborn/)
# ## Assignment description on [GitHub](https://github.com/uwescience/datasci_course_materials/blob/master/assignment6/crimeanalytics.md)
#
# This is an assignemnt for Coursera course by UW. It consists of 3 parts:
# 1. Try Bokeh and Seaborn
# 2. Exploration on "Project ideas"
# 3. Project report

# %% [markdown]
# # 1. Try Bokeh and Seaborn

# %% [markdown]
# The basic steps to creating plots with the bokeh.plotting interface are:
#
# * Prepare some data (in this case plain python lists).
# * Tell Bokeh where to generate output (in this case using output_file(), with the filename "lines.html").
# * Call figure() to create a plot with some overall options like title, tools and axes labels.
# * Add renderers (in this case, Figure.line) for our data, with visual customizations like colors, legends and widths to the plot.
# * Ask Bokeh to show() or save() the results.

# %%
# import bokeh.plotting as bk
from bokeh.plotting import figure, output_file, show, output_notebook, save
# bk.output_notebook()

# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# output to static HTML file
# output_file("lines.html", title="line plot example")
output_notebook()

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="Temp.", line_width=2)

# show the results
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
# ...

# %%
# prepare some data
x = [0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
y0 = [i**2 for i in x]
y1 = [10**i for i in x]
y2 = [10**(i**2) for i in x]

# output to static HTML file
output_notebook()
# output_file("log_lines.html")

# create a new plot
p = figure(
   tools="pan,box_zoom,reset,save",
   y_axis_type="log", y_range=[0.001, 10**11], title="log axis example",
   x_axis_label='sections', y_axis_label='particles'
)

# add some renderers
p.line(x, x, legend="y=x")
p.circle(x, x, legend="y=x", fill_color="white", size=8)
p.line(x, y0, legend="y=x^2", line_width=3)
p.line(x, y1, legend="y=10^x", line_color="red")
p.circle(x, y1, legend="y=10^x", fill_color="red", line_color="red", size=6)
p.line(x, y2, legend="y=10^x^2", line_color="orange", line_dash="4 4")

# show the results
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
# ...

# %%
import numpy as np

from bokeh.plotting import figure, output_file, show

# prepare some data
N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = [
    "#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)
]

# output to static HTML file (with CDN resources)
# output_file("color_scatter.html", title="color_scatter.py example", mode="cdn")
output_notebook()

TOOLS="resize,crosshair,pan,wheel_zoom,box_zoom,reset,box_select,lasso_select"

# create a new plot with the tools above, and explicit ranges
p = figure(tools=TOOLS, x_range=(0,100), y_range=(0,100))

# add a circle renderer with vectorized colors and sizes
p.circle(x,y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)

# show the results
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
# ...

# %%
from bokeh.plotting import gridplot

# prepare some data
N = 100
x = np.linspace(0, 4*np.pi, N)
y0 = np.sin(x)
y1 = np.cos(x)
y2 = np.sin(x) + np.cos(x)

# output to static HTML file
output_file("linked_panning.html")

# create a new plot
s1 = figure(width=250, plot_height=250, title=None)
s1.circle(x, y0, size=10, color="navy", alpha=0.5)

# NEW: create a new plot and share both ranges
s2 = figure(width=250, height=250, x_range=s1.x_range, y_range=s1.y_range, title=None)
s2.triangle(x, y1, size=10, color="firebrick", alpha=0.5)

# NEW: create a new plot and share only one range
s3 = figure(width=250, height=250, x_range=s1.x_range, title=None)
s3.square(x, y2, size=10, color="olive", alpha=0.5)

# NEW: put the subplots in a gridplot
p = gridplot([[s1, s2, s3]], toolbar_location=None)

# show the results
show(p)
# Out:
#     <div class="plotdiv" id="d73d17c4-ce83-4077-a879-d70fb0cd86e2"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
# ...

# %%
from bokeh.models import ColumnDataSource

# prepare some date
N = 300
x = np.linspace(0, 4*np.pi, N)
y0 = np.sin(x)
y1 = np.cos(x)

# output to static HTML file
output_file("linked_brushing.html")

# NEW: create a column data source for the plots to share
source = ColumnDataSource(data=dict(x=x, y0=y0, y1=y1))

TOOLS = "pan,wheel_zoom,box_zoom,reset,save,box_select,lasso_select"

# create a new plot and add a renderer
left = figure(tools=TOOLS, width=350, height=350, title=None)
left.circle('x', 'y0', source=source)

# create another new plot and add a renderer
right = figure(tools=TOOLS, width=350, height=350, title=None)
right.circle('x', 'y1', source=source)

# put the subplots in a gridplot
p = gridplot([[left, right]])

# show the results
show(p)
# Out:
#     <div class="plotdiv" id="ff54c46f-299c-4954-86d0-8c5f539b61a4"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="white", context="talk")
rs = np.random.RandomState(7)


# Set up the matplotlib figure
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(8, 6), sharex=True)

# Generate some sequential data
x = np.array(list("ABCDEFGHI"))
y1 = np.arange(1, 10)
sns.barplot(x, y1, palette="BuGn_d", ax=ax1)
ax1.set_ylabel("Sequential")

# Center the data to make it diverging
y2 = y1 - 5
sns.barplot(x, y2, palette="RdBu_r", ax=ax2)
ax2.set_ylabel("Diverging")

# Randomly reorder the data to make it qualitative
y3 = rs.choice(y1, 9, replace=False)
sns.barplot(x, y3, palette="Set3", ax=ax3)
ax3.set_ylabel("Qualitative")

# Finalize the plot
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=3)

# %% [markdown]
# # 2. Exploration on "Project ideas"
#
# <pre>
#
#
# You may want to consider one or more of the following types of questions when developing your submission.
#
# For either city, how do incidents vary by time of day? Which incidents are most common in the evening? During what periods of the day are robberies most common?
# For either city, how do incidents vary by neighborhood? Which incidents are most common in the city center? In what areas or neighborhoods are robberies or thefts most common?
# For either city, how do incidents vary month to month in the Summer 2014 dataset?
# For either city, which incident types tend to correlate with each other on a day-by-day basis?
# Advanced What can we infer broadly about the differences in crime patterns between Seattle and San Francisco? Does one city tend to have more crime than the other, per capita? Do the relative frequencies of types of incidents change materially between the two cities? (NOTE: The two datasets do not have the same schema, so comparisons will require some work and some assumptions. This will require extra work, but you will be working at the forefront of what is known!)
# Advanced For either city, do certain crimes correlate with environmental factors such as temperature? (To answer this kind of question, you will need to identify and use external data sources!)
#
# </pre>

# %%
import pandas as pd

# %%
sanf = pd.read_csv('sanfrancisco_incidents_summer_2014.csv')
seat = pd.read_csv('seattle_incidents_summer_2014.csv')
# Out:
# C:\Users\jiancheng\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2902: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sanf.head()
# Out:
#    IncidntNum       Category                      Descript DayOfWeek  \
# 0   140734311          ARSON            ARSON OF A VEHICLE    Sunday
# 1   140736317   NON-CRIMINAL                 LOST PROPERTY    Sunday
# 2   146177923  LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO    Sunday
# 3   146177531  LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO    Sunday
# 4   140734220   NON-CRIMINAL                FOUND PROPERTY    Sunday
#
#          Date   Time PdDistrict Resolution                    Address  \
# 0  08/31/2014  23:50    BAYVIEW       NONE  LOOMIS ST / INDUSTRIAL ST
# 1  08/31/2014  23:45    MISSION       NONE     400 Block of CASTRO ST
# 2  08/31/2014  23:30   SOUTHERN       NONE   1000 Block of MISSION ST
# 3  08/31/2014  23:30   RICHMOND       NONE        FULTON ST / 26TH AV
# 4  08/31/2014  23:23   RICHMOND       NONE   800 Block of LA PLAYA ST
#
#             X          Y                               Location  \
# ...

# %%
seat.head()
# Out:
#    RMS CDW ID  General Offense Number Offense Code  Offense Code Extension  \
# 0      483839              2015218538         2202                       0
# 1      481252              2015213067         2610                       0
# 2      481375              2015210301         2316                       0
# 3      481690              2015209327         2599                       0
# 4      478198              2015207880         2399                       3
#
#            Offense Type Summary Offense Code Summarized Offense Description  \
# 0    BURGLARY-FORCE-RES                 2200                       BURGLARY
# 1  FRAUD-IDENTITY THEFT                 2600                          FRAUD
# 2            THEFT-MAIL                 2300                     MAIL THEFT
# 3           COUNTERFEIT                 2500                    COUNTERFEIT
# 4             THEFT-OTH                 2300                 OTHER PROPERTY
#
# ...

# %%
sanf.tail()
# Out:
#        IncidntNum       Category                     Descript DayOfWeek  \
# 28988   140763495   NON-CRIMINAL                LOST PROPERTY    Sunday
# 28989   140779301        ASSAULT         THREATS AGAINST LIFE    Sunday
# 28990   140908839  LARCENY/THEFT  PETTY THEFT FROM A BUILDING    Sunday
# 28991   140908839  LARCENY/THEFT          PETTY THEFT BICYCLE    Sunday
# 28992   141017556   NON-CRIMINAL                LOST PROPERTY    Sunday
#
#              Date   Time PdDistrict Resolution                   Address  \
# 28988  06/01/2014  00:01   SOUTHERN       NONE    700 Block of MARKET ST
# 28989  06/01/2014  00:01   SOUTHERN       NONE      300 Block of KING ST
# 28990  06/01/2014  00:01   NORTHERN       NONE  900 Block of FRANKLIN ST
# 28991  06/01/2014  00:01   NORTHERN       NONE  900 Block of FRANKLIN ST
# 28992  06/01/2014  00:01   NORTHERN       NONE    600 Block of LARKIN ST
#
#                 X          Y                               Location  \
# ...

# %%
from bokeh.charts import Bar
from bokeh.charts.attributes import cat
output_notebook()

df = pd.DataFrame()
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df['weekday'] = weekdays
df['week_count'] = [sanf.groupby('DayOfWeek').count()['IncidntNum'][weekday] for weekday in weekdays]

bar = Bar(df, label = cat(columns = 'weekday',sort = False),values = 'week_count',color = 'wheat',y_range= [3500,4500], plot_width=800, ylabel = 'Incident count')
show(bar)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
# ...

# %%
df
# Out:
#      weekday  week_count
# 0     Monday        4005
# 1    Tuesday        3930
# 2  Wednesday        4102
# 3   Thursday        3968
# 4     Friday        4451
# 5   Saturday        4319
# 6     Sunday        4218

# %%
week_count = sanf.groupby('DayOfWeek').count()['IncidntNum']
week_count
# Out:
# DayOfWeek
# Friday       4451
# Monday       4005
# Saturday     4319
# Sunday       4218
# Thursday     3968
# Tuesday      3930
# Wednesday    4102
# Name: IncidntNum, dtype: int64

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set(style="white", context="talk")
rs = np.random.RandomState(7)


# Set up the matplotlib figure
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(8, 6), sharex=True)

# Generate some sequential data
x = np.array(list("ABCDEFGHI"))
y1 = np.arange(1, 10)
sns.barplot(x, y1, palette="BuGn_d", ax=ax1)
ax1.set_ylabel("Sequential")

# Center the data to make it diverging
y2 = y1 - 5
sns.barplot(x, y2, palette="RdBu_r", ax=ax2)
ax2.set_ylabel("Diverging")

# Randomly reorder the data to make it qualitative
y3 = rs.choice(y1, 9, replace=False)
sns.barplot(x, y3, palette="Set3", ax=ax3)
ax3.set_ylabel("Qualitative")

# Finalize the plot
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=3)

# %%
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
week_count = [sanf.groupby('DayOfWeek').count()['IncidntNum'][weekday] for weekday in weekdays]
g = sns.barplot(weekdays, week_count, palette = 'Set3')
g.set_xlabel('Weekday')
g.set_ylabel('Incident count')
g.set_title('Summer (Jun - Aug), 2014, San Francisco')
g.set_ylim([3700, 4500])
# Out:
# (3700, 4500)

# %%
sanf['Hour'] = sanf['Time'].map(lambda x: x[:2])
hoursersis = sanf.groupby('Hour').count()['IncidntNum']
ax = sns.barplot(hoursersis.index, hoursersis / 92., palette = 'Blues')
ax.set_xlabel('Hour in a day')
ax.set_ylabel('Average incident')
ax.set_title('Summer (Jun - Aug), 2014, San Francisco')
#ax.set_ylim([3700, 4500])

# %%
len(sanf['Date'].unique())
# Out:
# 92

# %%
sanf['Period'] = sanf['Hour'].map(lambda x: ['Morning (04:00 - 11:59)', 'Afternoon (12:00 - 19:59)', 'Evening (20:00 - 03:59)'][(int(x)-4)/8])

# %%
in_days = ['Morning (04:00 - 11:59)', 'Afternoon (12:00 - 19:59)', 'Evening (20:00 - 03:59)']
day_count = [sanf.groupby('Period').count()['IncidntNum'][in_day] for in_day in in_days]
g = sns.barplot(in_days, day_count, palette = 'Greens')
g.set_ylabel('Incident count')
g.set_title('Summer (Jun - Aug), 2014, San Francisco')

# %%
(lambda x: ['Morning', 'Afternoon', 'Evening'][(int(x)-4)/8])('20')
# Out:
# 'Evening'

# %%
catsersis = sanf.groupby('Category').count()['IncidntNum'].sort_values()
ax = sns.barplot(catsersis.index, catsersis, palette = 'Reds')
ax.set_xlabel('Category')
ax.set_ylabel('Incident Count')
ax.set_title('Summer (Jun - Aug), 2014, San Francisco')
catsersis
# Out:
# Category
# BRIBERY                           1
# PORNOGRAPHY/OBSCENE MAT           1
# GAMBLING                          1
# LOITERING                         3
# BURGLARY                          6
# EXTORTION                         7
# STOLEN PROPERTY                   8
# EMBEZZLEMENT                     10
# FAMILY OFFENSES                  10
# SUICIDE                          14
# VANDALISM                        17
# FORGERY/COUNTERFEITING           18
# DISORDERLY CONDUCT               31
# LIQUOR LAWS                      42
# RUNAWAY                          61
# ARSON                            63
# DRIVING UNDER THE INFLUENCE     100
# PROSTITUTION                    112
# KIDNAPPING                      117
# DRUNKENNESS                     147
# FRAUD                           242
# TRESPASS                        281
# ROBBERY                         308
# WEAPON LAWS                     354
# SECONDARY CODES                 442
# MISSING PERSON                 1266
# ...

# %%
in_days = ['Morning (04:00 - 11:59)', 'Afternoon (12:00 - 19:59)', 'Evening (20:00 - 03:59)']
robbery_day_count = [sanf[sanf['Category'] == 'ROBBERY'].groupby('Period').count()['IncidntNum'][in_day] for in_day in in_days]
g = sns.barplot(in_days, robbery_day_count, palette = 'Greens')
g.set_ylabel('Robbery count')
g.set_title('Summer (Jun - Aug), 2014, San Francisco')

# %%
robbery_hoursersis = sanf[sanf['Category'] == 'ROBBERY'].groupby('Hour').count()['IncidntNum']
ax = sns.barplot(robbery_hoursersis.index, robbery_hoursersis / 92., palette = 'Blues')
ax.set_xlabel('Hour in a day')
ax.set_ylabel('Average incident')
ax.set_title('Summer (Jun - Aug), 2014, San Francisco')

# %%
f, (ax1,ax2) = plt.subplots(2,1,figsize=(20, 6),sharex = True)
robbery_area_sersis = sanf[sanf['Category'] == 'ROBBERY'].groupby('PdDistrict').count()['IncidntNum']
area_sersis = sanf.groupby('PdDistrict').count()['IncidntNum']
sns.barplot(area_sersis.index, area_sersis, ax=ax1)
sns.barplot(robbery_area_sersis.index, robbery_area_sersis, ax=ax2)
ax1.set_ylabel('Total Incident')
ax2.set_ylabel('Robbery')
ax1.set_title('Summer (Jun - Aug), 2014, San Francisco')

# %%
x = np.linspace(0, 5, 10)
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");

# %%
x = np.linspace(0, 10, 10)
fig, ax = plt.subplots()
ax.plot(x, x,'-.',label = 'Consumption = Y')
ax.plot(x, 0.9*x, label = 'Consumption = Y - 0.1Y')
ax.plot(x, x - 0.44, label = 'Consumption = Y - 1.1 * 0.4')
ax.plot(x, 0.7*x, label = 'Consumption = Y - 0.3Y')
ax.set_xlim([0, 6])
ax.set_ylim([0, 6])
ax.set_xlabel('Output-Y')
ax.set_ylabel('Consumption')
ax.legend(loc=2); # upper left corner


ax.plot(np.ones(10), np.linspace(0, 4, 10), 'y--')
ax.plot(np.ones(10)*1.47, np.linspace(0, 1.026667, 10), 'y--')
ax.plot(np.ones(10)*2, np.linspace(0, 4, 10), 'y--')
ax.plot(np.ones(10)*4.4, np.linspace(0, 3.96, 10), 'y--')

ax.text(1, 0.9, 'x', fontsize=10, color="black")
ax.text(0.8, 0.9, "N'", fontsize=15, color="black")

ax.text(1, 0.7, 'x', fontsize=10, color="black")
ax.text(1.05, 0.7, 'N', fontsize=15, color="black")

ax.text(1, 0.56, 'x', fontsize=10, color="black")
ax.text(1.1, 0.36, 'R', fontsize=15, color="black")

ax.text(1.466667, 1.026667, 'x', fontsize=10, color="black")
ax.text(1.56667, 0.826667, 'T', fontsize=15, color="black")

ax.text(2, 1.8, 'x', fontsize=10, color="black")
ax.text(2.1, 1.9, "N'", fontsize=15, color="black")

ax.text(2, 1.4, 'x', fontsize=10, color="black")
ax.text(2.15, 1.3, 'N', fontsize=15, color="black")

ax.text(2, 1.56, 'x', fontsize=10, color="black")
ax.text(1.8, 1.6, 'R', fontsize=15, color="black")

ax.text(4.4, 3.96, 'x', fontsize=10, color="black")
ax.text(4.5, 3.76, "T'", fontsize=15, color="black")

ax.text(0.7, -0.5, r"$\overline{Y} - V = 1$", fontsize=12, color="black")
ax.text(1.1, -0.2, r"$Y_T = 1.4667$", fontsize=12, color="black")
ax.text(2.1, 0.1, r"$\overline{Y} = 2$", fontsize=12, color="black")
ax.text(4.1, -0.2, r"$Y_T' = 4.4$", fontsize=12, color="black")

ax.plot(np.linspace(1.1, 1.1, 1),np.ones(1)*3.6,  'b<')
ax.plot(np.linspace(1.9, 1.9, 1),np.ones(1)*3.6,  'b>')
ax.plot(np.linspace(1.1, 1.9, 10),np.ones(10)*3.6,  'b-.')
ax.text(1.3, 3.4, r"$V = 1$", fontsize=12, color="black")

# %%
# x = np.linspace(0, 10, 10)
fig, ax = plt.subplots()
ax.plot(x, x,'-.',label = 'Consumption = Y')
ax.plot(x, x - 0.44, label = 'Consumption = Y - 1.1 * 0.4')
ax.plot(x, 0.7*x, label = 'Consumption = Y - 0.3Y')
ax.set_xlim([0, 2.1])
ax.set_ylim([0, 3])
ax.set_xlabel('Output-Y')
ax.set_ylabel('Consumption')
ax.legend(loc=2); # upper left corner


ax.plot(np.ones(10), np.linspace(0, 4, 10), 'y--')
ax.plot(np.ones(10)*1.47, np.linspace(0, 1.026667, 10), 'y--')
ax.plot(np.ones(10)*2, np.linspace(0, 4, 10), 'y--')
ax.plot(np.ones(10)*4.4, np.linspace(0, 3.96, 10), 'y--')

ax.text(1, 0.7, 'x', fontsize=10, color="black")
ax.text(1.05, 0.7, 'N', fontsize=15, color="black")

ax.text(1, 0.56, 'x', fontsize=10, color="black")
ax.text(1.05, 0.46, 'R', fontsize=15, color="black")

ax.text(1.466667, 1.026667, 'x', fontsize=10, color="black")
ax.text(1.5, 0.9, 'T', fontsize=15, color="black")

ax.text(2, 1.4, 'x', fontsize=10, color="black")
ax.text(2.05, 1.3, 'N', fontsize=15, color="black")

ax.text(2, 1.56, 'x', fontsize=10, color="black")
ax.text(1.95, 1.6, 'R', fontsize=15, color="black")

ax.text(0.95, 0.05, r"$\overline{Y} - V = 1$", fontsize=12, color="black")
ax.text(1.4, 0.05, r"$Y_T = 1.4667$", fontsize=12, color="black")
ax.text(1.95, 0.05, r"$\overline{Y} = 2$", fontsize=12, color="black")

ax.plot(1,2.5,  'b<')
ax.plot(2,2.5,  'b>')
ax.plot(np.linspace(1, 2, 10),np.ones(10)*2.5,  'b-.')
ax.text(1.4, 2.6, r"$V = 1$", fontsize=12, color="black")
